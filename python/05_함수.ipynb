# %% [markdown]
# # 05_함수
#
# ```python
# def 함수_이름(매개변수 <-input):
#
#     [함수로 묶을 코드]
#
#     return 반환값-output
# ```

# %%
# name: plus_one / in: 숫자 / out: 숫자 + 1

# 함수 정의(define)

def plus_one(x):
    return x + 1

# 함수 실행/호출(call)
plus_one(99)
# Out:
# 100

# %%
# n번 인사하는 함수
# name: hello_ntimes / in: 숫자 / out (return) 없음

#정의
def n_hello(num):
    # 임시변수를 쓰지 않는 반복문일 경우
    # 임시변수 이름을 _로 쓰기로 함. 파이썬 국룰
    for _ in range(num):
        print('방가방가', i+1)
        
#  _ 도 함수명으로 쓸 수 있다. _ = 1 도 가능.      


#호출
n_hello(5)
# Out:
# 방가방가
# 방가방가
# 방가방가
# 방가방가
# 방가방가

# %%
# 3제곱 해주는 함수
# name: cube, in: 숫자 1개, out: 숫자의 세제곱

# %%
# 원기둥의 부피를 구하는 함수
# name: cylinder, in: 반지름/높이, out: 부피(pi * r^2 * h)

# %%
# 리스트 내부의 숫자들의 평균을 구해주는 함수
# name: get_avg, in: 숫자들로 만들어진 리스트, out: 평균

# %%
# 비밀번호 체크해주는 함수 (숫자 포함, 8글자 이상)
# name: check_pw, in: 비밀번호 문자열, out: True/False

# %%
# BMI 기준으로, 비만여부 확인해주는 함수 (BMI = 체중(kg) / 키(m)^2)
# 남성 27 이상일 경우 비만
# 여성 25 이상일 경우 비만
